# %%
import os
import pandas as pd
import glob
current_directory = os.path.join('/opt', 'home', 's3934056')
results_directory_path = os.path.join(current_directory, 'results', 'metric', 'KMeans','2.0.5', '**', '**', 'drift_results_v4.csv')
results_directory_path
# Out:
# '.\\results\\metric\\KMeans\\2.0.5\\**\\**\\drift_results_v4.csv'

# %%
results_directory_path = r'../results/metrics/KMeans/2.0.5/**/**/drift_results_v4.csv'
# Use glob to find all CSV files matching the pattern
csv_files = glob.glob(results_directory_path, recursive=True)
print(len(csv_files))
# Out:
# 33

# %%
# Use glob to find all CSV files matching the pattern
csv_files = glob.glob(results_directory_path, recursive=True)
    
# Read each CSV file into a pandas DataFrame and store them in a list
dataframes = [pd.read_csv(file) for file in csv_files]
    
# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)
    
# Save the combined DataFrame to a new CSV file
combined_df.to_csv(f'KMeans_drift_combined_results.csv', index=False)

# %%
# Read the combined CSV into a DataFrame
df = pd.read_csv(f'KMeans_drift_combined_results.csv')



# Data Overview
print(df.describe())
# Out:
#        Training Time  Prediction Time          AMI          ARI  \
# count    1485.000000      1485.000000  1485.000000  1485.000000
# mean       11.244122         0.004360     0.906247     0.828678
# std        21.467756         0.010167     0.077133     0.149323
# min         0.144851         0.000740     0.751311     0.478573
# 25%         0.175106         0.000763     0.830952     0.696662
# 50%         0.188966         0.000827     0.909197     0.844941
# 75%         8.203545         0.001737     0.983290     0.974380
# max        62.881626         0.052232     1.000000     1.000000
#
#        Calinski-Harabasz Score  Davies-Bouldin Score  Completeness Score  \
# count              1485.000000           1485.000000         1485.000000
# mean              24908.344748              0.465254            0.921218
# std               45311.357749              0.199014            0.065399
# min                 236.186836              0.036494            0.766796
# 25%                1312.243244              0.307411            0.861262
# 50%                3927.523971              0.519249            0.919737
# 75%               31150.934636              0.621791            0.985459
# max              190292.584051              0.895060            1.000000
#
#        Fowlkes-Mallows Score  Homogeneity  Completeness    V-Measure  \
# count            1485.000000  1485.000000   1485.000000  1485.000000
# mean                0.835678     0.917207      0.921218     0.919199
# std                 0.144368     0.069011      0.065399     0.067188
# min                 0.488463     0.759663      0.766796     0.763213
# 25%                 0.711322     0.854753      0.861262     0.858113
# 50%                 0.852666     0.913072      0.919737     0.915816
# 75%                 0.975550     0.984778      0.985459     0.985164
# max                 1.000000     1.000000      1.000000     1.000000
#
#        Mutual Information  Normalized Mutual Information  Silhouette Score  \
# count         1485.000000                    1485.000000       1485.000000
# mean             2.996771                       0.919199          0.650697
# std              0.633580                       0.067188          0.159342
# min              2.221776                       0.763213          0.359618
# 25%              2.503272                       0.858113          0.520174
# 50%              2.745361                       0.915816          0.613327
# 75%              3.486225                       0.985164          0.769263
# max              4.564228                       1.000000          0.975531
#
#           Accuracy
# count  1485.000000
# mean      0.900792
# std       0.091807
# min       0.648520
# 25%       0.824219
# 50%       0.914062
# 75%       0.987749
# max       1.000000

# %%
df.head()
# Out:
#                     Timestamp Dataset Clustering Algorithm  \
# 0  2024-04-04 08:44:59.708140      a1               KMeans
# 1  2024-04-04 08:45:00.093164      a1               KMeans
# 2  2024-04-04 08:45:00.464935      a1               KMeans
# 3  2024-04-04 08:45:00.837694      a1               KMeans
# 4  2024-04-04 08:45:01.208097      a1               KMeans
#
#                                    Algorithm Details      Drift Type  \
# 0  {'algorithm': 'full', 'copy_x': True, 'init': ...  Gaussian Shift
# 1  {'algorithm': 'full', 'copy_x': True, 'init': ...  Gaussian Shift
# 2  {'algorithm': 'full', 'copy_x': True, 'init': ...  Gaussian Shift
# 3  {'algorithm': 'full', 'copy_x': True, 'init': ...  Gaussian Shift
# 4  {'algorithm': 'full', 'copy_x': True, 'init': ...  Gaussian Shift
#
#   Drift Level  Training Time  Prediction Time       AMI       ARI  ...  \
# 0        MILD       0.295866         0.000962  0.775203  0.617247  ...
# 1        MILD       0.346694         0.000951  0.790746  0.626101  ...
# 2        MILD       0.338029         0.000857  0.772728  0.615093  ...
# 3        MILD       0.338933         0.000969  0.795980  0.650021  ...
# 4        MILD       0.336610         0.000977  0.803578  0.669799  ...
#
#    Davies-Bouldin Score  Completeness Score  Fowlkes-Mallows Score  \
# 0              0.689637            0.803839               0.637926
# 1              0.655282            0.817955               0.646424
# 2              0.686570            0.800924               0.635692
# 3              0.657124            0.818563               0.667930
# 4              0.664151            0.824880               0.686591
#
#    Homogeneity  Completeness  V-Measure  Mutual Information  \
# 0     0.788772      0.803839   0.796234            2.359202
# 1     0.802915      0.817955   0.810365            2.401505
# 2     0.787237      0.800924   0.794021            2.354610
# 3     0.811703      0.818563   0.815119            2.427788
# 4     0.819135      0.824880   0.821998            2.450019
#
#    Normalized Mutual Information  Silhouette Score  Accuracy
# 0                       0.796234          0.485398  0.760000
# 1                       0.810365          0.499346  0.766667
# 2                       0.794021          0.461189  0.765333
# 3                       0.815119          0.497428  0.808000
# 4                       0.821998          0.496672  0.818667
#
# [5 rows x 21 columns]

# %%
# Define drift types and levels
drift_types = ['Knock-out', 'Gaussian Shift', 'Concept Drift']
drift_levels = ['MILD', 'MODERATE', 'SEVERE']

cache_file_path  = '../cache/2.0.5/'

# Iterate over drift types and levels
for drift_type in drift_types:
    for drift_level in drift_levels:
        # Filter the DataFrame for the current drift type and level
        filtered_data = df[(df['Drift Type'] == drift_type) & (df['Drift Level'] == drift_level)]
        
        
        # Save the filtered data to a CSV file
        file_name = cache_file_path + f"filtered_data_{drift_type}_{drift_level}.csv"
        filtered_data.to_csv(file_name, index=False)
# Out:
# Knock-out MILD
# Knock-out MODERATE
# Knock-out SEVERE
# Gaussian Shift MILD
# Gaussian Shift MODERATE
# Gaussian Shift SEVERE
# Concept Drift MILD
# Concept Drift MODERATE
# Concept Drift SEVERE

# %%
csv_files = glob.glob(cache_file_path + '/*.csv' , recursive=True)
len(csv_files)
# Out:
# 6

# %%
# Specify the columns for which to calculate the mean
metrics_columns = ['Training Time', 'Prediction Time', 'AMI', 'ARI', 'Calinski-Harabasz Score', 
                   'Davies-Bouldin Score', 'Completeness Score', 'Fowlkes-Mallows Score', 
                   'Homogeneity', 'Completeness', 'V-Measure', 'Mutual Information', 
                   'Normalized Mutual Information', 'Silhouette Score', 'Accuracy']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for file in csv_files:
    df = pd.read_csv(file)
    # print()
    print(file)
    # # Group the data by the "Dataset" column and calculate the mean of each metric
    df = df.groupby("Dataset")[metrics_columns].mean()
    # 
    # print(mean_metrics.describe())
        # Performance Metrics Distribution
    metrics = ['Davies-Bouldin Score', 'Calinski-Harabasz Score', 'Silhouette Score', 'Accuracy']
    plt.figure(figsize=(20, 5))
    for i, metric in enumerate(metrics, 1):
        plt.subplot(1, 5, i)
        sns.histplot(df[metric], kde=True)
        plt.title(f'Distribution of {metric}')
    plt.tight_layout()
    plt.show()
    
    # # Correlation Analysis
    # correlation_matrix = df[metrics].corr()
    # plt.figure(figsize=(8, 6))
    # sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
    # plt.title('Correlation between Metrics')
    # plt.show()
# Out:
# ../cache/2.0.5\filtered_data_Gaussian Shift_MILD.csv
# ../cache/2.0.5\filtered_data_Gaussian Shift_MODERATE.csv
# ../cache/2.0.5\filtered_data_Gaussian Shift_SEVERE.csv
# ../cache/2.0.5\filtered_data_Knock-out_MILD.csv
# ../cache/2.0.5\filtered_data_Knock-out_MODERATE.csv
# ../cache/2.0.5\filtered_data_Knock-out_SEVERE.csv

# %%
for file in csv_files:
    df = pd.read_csv(file)
    # print()
    print(file)
    # # Group the data by the "Dataset" column and calculate the mean of each metric
    df = df.groupby("Dataset")[metrics_columns].mean()
    # 
    print(df[['Davies-Bouldin Score', 'Calinski-Harabasz Score', 'Silhouette Score', 'Accuracy']].describe())
# Out:
# ../cache/2.0.5\filtered_data_Gaussian Shift_MILD.csv
#        Davies-Bouldin Score  Calinski-Harabasz Score  Silhouette Score  \
# count             11.000000                11.000000         11.000000
# mean               0.457460             21982.972340          0.650089
# std                0.153225             36242.169881          0.138922
# min                0.217787              1675.908390          0.430743
# 25%                0.331267              3984.616364          0.543070
# 50%                0.432570              8300.043802          0.682524
# 75%                0.586100             21153.599248          0.762428
# max                0.653687            126847.697249          0.855722
#
#         Accuracy
# count  11.000000
# mean    0.885405
# std     0.056856
# min     0.724400
# 25%     0.884355
# 50%     0.899840
# 75%     0.914062
# max     0.925781
# ../cache/2.0.5\filtered_data_Gaussian Shift_MODERATE.csv
#        Davies-Bouldin Score  Calinski-Harabasz Score  Silhouette Score  \
# count             11.000000                11.000000         11.000000
# mean               0.513216             11703.646851          0.614969
# std                0.134347             23310.709849          0.127581
# min                0.270905              1427.105311          0.419701
# 25%                0.433468              1831.571600          0.511949
# 50%                0.475621              2212.379800          0.650989
# 75%                0.635390              3437.378112          0.718129
# max                0.668026             76804.866671          0.824433
#
#         Accuracy
# count  11.000000
# mean    0.880733
# std     0.071399
# min     0.689964
# 25%     0.872720
# 50%     0.903516
# 75%     0.925000
# max     0.940234
# ../cache/2.0.5\filtered_data_Gaussian Shift_SEVERE.csv
#        Davies-Bouldin Score  Calinski-Harabasz Score  Silhouette Score  \
# count             11.000000                11.000000         11.000000
# mean               0.604054              5186.673441          0.567802
# std                0.121738              9275.988212          0.122329
# min                0.442761               724.525251          0.391107
# 25%                0.504475               751.557751          0.465344
# 50%                0.587916               838.117086          0.599820
# 75%                0.692855              2210.792943          0.677250
# max                0.794459             27506.585447          0.736517
#
#         Accuracy
# count  11.000000
# mean    0.835446
# std     0.062705
# min     0.663128
# 25%     0.831498
# 50%     0.857422
# 75%     0.872266
# max     0.883984
# ../cache/2.0.5\filtered_data_Knock-out_MILD.csv
#        Davies-Bouldin Score  Calinski-Harabasz Score  Silhouette Score  \
# count             11.000000                11.000000         11.000000
# mean               0.346652             49072.044930          0.729504
# std                0.218968             65457.459491          0.179542
# min                0.037402              1946.026024          0.452342
# 25%                0.146979              6506.054446          0.589107
# 50%                0.294719             18909.362052          0.771571
# 75%                0.528180             51806.114485          0.891847
# max                0.628696            189610.985256          0.974761
#
#         Accuracy
# count  11.000000
# mean    0.968259
# std     0.059849
# min     0.800289
# 25%     0.976949
# 50%     0.992063
# 75%     1.000000
# max     1.000000
# ../cache/2.0.5\filtered_data_Knock-out_MODERATE.csv
#        Davies-Bouldin Score  Calinski-Harabasz Score  Silhouette Score  \
# count             11.000000                11.000000         11.000000
# mean               0.346437             48813.826001          0.730176
# std                0.219044             65094.239010          0.180310
# min                0.037385              1892.320179          0.452153
# 25%                0.146152              6478.373225          0.588296
# 50%                0.294772             20635.683413          0.769499
# 75%                0.528052             50489.843632          0.893267
# max                0.628786            188819.563907          0.974962
#
#         Accuracy
# count  11.000000
# mean    0.967979
# std     0.060112
# min     0.799654
# 25%     0.976637
# 50%     0.991870
# 75%     1.000000
# max     1.000000
# ../cache/2.0.5\filtered_data_Knock-out_SEVERE.csv
#        Davies-Bouldin Score  Calinski-Harabasz Score  Silhouette Score  \
# count             11.000000                11.000000         11.000000
# mean               0.344733             48542.646532          0.730871
# std                0.219856             64358.554861          0.181310
# min                0.038008              1819.855278          0.451850
# 25%                0.145133              6364.686386          0.586946
# 50%                0.296493             25625.668721          0.765686
# 75%                0.528709             48517.954021          0.894389
# max                0.630111            187787.987684          0.975037
#
#         Accuracy
# count  11.000000
# mean    0.967718
# std     0.060366
# min     0.798813
# 25%     0.976201
# 50%     0.991597
# 75%     1.000000
# max     1.000000
